# %% [markdown]
# # SIRCSS-CTA: Assignment COLAB Template
#
# This template contain information on using Google COLAB to run code in the assignments of the course. Just as R-markdown, COLAB is built upon markdown. More information on how you can add equations and format your report you can find [here](https://colab.research.google.com/notebooks/markdown_guide.ipynb).
#
# When using this template for assignments report, just keep the "Setting the stage" part below. That will install everything you need.

# %% [markdown]
# ## Setting the stage
# We start by installing nessecary packages for the course. This include the material for all assignments using R. This can take a couple of minutes.

# %%
install.packages("remotes")
remotes::install_github("MansMeg/IntroML", subdir = "rpackage")
install.packages("tidytext")
install.packages("topicmodels")
remotes::install_github('MansMeg/ropenaiapi')

# %% [markdown]
# ## Running R code in COLAB
# We can run R code in COLAB just as we would run R code in R-Studio. Just add a code block with your R code and press the run button.

# %%
x <- seq(0, 2*pi, length.out=50)
plot(x, sin(x))
# Out:
# plot without title
